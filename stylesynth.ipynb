# %%
import matplotlib.pyplot as plt
from stylesynth import StyleSynth

# %%
ss = StyleSynth()

# %%
ss.train(12, 128, 2, 3)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 10.9MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 169kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.07MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 12.1MB/s]
#   0%|          | 0/12 [00:00<?, ?it/s]INFO:StyleSynth_Logger:Epoch 1 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.16810671408989317
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
#   8%|▊         | 1/12 [00:31<05:43, 31.25s/it]INFO:StyleSynth_Logger:Epoch 2 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.11413795262629635
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
#  25%|██▌       | 3/12 [01:27<04:17, 28.61s/it]INFO:StyleSynth_Logger:Epoch 4 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.1006599113590321
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
#  42%|████▏     | 5/12 [02:23<03:16, 28.05s/it]INFO:StyleSynth_Logger:Epoch 6 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.09706522653754497
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
#  58%|█████▊    | 7/12 [03:19<02:19, 27.97s/it]INFO:StyleSynth_Logger:Epoch 8 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.09400217418969223
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
#  75%|███████▌  | 9/12 [04:15<01:23, 27.91s/it]INFO:StyleSynth_Logger:Epoch 10 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.09298486558131369
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
#  92%|█████████▏| 11/12 [05:11<00:27, 27.94s/it]INFO:StyleSynth_Logger:Epoch 12 / 12
# INFO:StyleSynth_Logger:Average Loss Per Image: 0.09199322238428286
# INFO:StyleSynth_Logger:Clothing types: ['Sandal', 'Sneaker', 'Trouser']
# 100%|██████████| 12/12 [05:40<00:00, 28.39s/it]

# %%
# generate an image for each image class
CLOTHING_TYPES = [
    'Top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker',
    'Bag', 'Boot']
imgs = ss.generate(CLOTHING_TYPES)
for i in range(len(imgs)):
    print(f'\nClothing type: {CLOTHING_TYPES[i]}')
    plt.figure(figsize=(2, 2))
    plt.axis('off')
    plt.imshow(imgs[i])
    plt.show()
# Out:
# Clothing type: Top
# Clothing type: Trouser
# Clothing type: Pullover
# Clothing type: Dress
# Clothing type: Coat
# Clothing type: Sandal
# Clothing type: Shirt
# Clothing type: Sneaker
# Clothing type: Bag
# Clothing type: Boot
